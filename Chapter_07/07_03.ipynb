# %%
analgesics = ["paracetamol","ibuprofen","diclofenac"]

# %%
for item in analgesics:
    print(item)
# Out:
# paracetamol
# ibuprofen
# diclofenac

# %%
for analgesic in analgesics:
    print(analgesic)
# Out:
# paracetamol
# ibuprofen
# diclofenac

# %%
numbers = [10,20,30,40,50]

# %%
double_number = []
for number in numbers:
    double_number.append(number*2)

# %%
double_number
# Out:
# [20, 40, 60, 80, 100]

# %%
for item in double_number:
    if item == 60:
        continue
    print(item)
# Out:
# 20
# 40
# 80
# 100

# %%
string_value = "omeprazole"
for character in string_value:
    print(character)
# Out:
# o
# m
# e
# p
# r
# a
# z
# o
# l
# e
