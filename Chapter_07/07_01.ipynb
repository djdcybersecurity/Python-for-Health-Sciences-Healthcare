# %%
100 + 100
# Out:
# 200

# %%
200 + 100
# Out:
# 300

# %%
def addition(value_1, value_2):
    result = value_1 + value_2
    return result

# %%
addition(200,100)
# Out:
# 300

# %%
addition(1000000, 100000)
# Out:
# 1100000

# %%
addition("hydro","chlorothiazide")
# Out:
# 'hydrochlorothiazide'

# %%
def bienvenue():
    print("Welcome to our Laboratory")

# %%
bienvenue()
# Out:
# Welcome to our Laboratory
