# %%
total_quantity_dispensed = 6 * 7
#total quantity of medication taken two tablets twice daily for one week use

# %%
total_quantity_dispensed = 6 * 7
"""
total quantity of medication taken two tablets twice daily for one week use
remember a week is 7 days in total
the dosage of this tablet is 500mg each
"""
