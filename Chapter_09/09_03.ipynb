# %%
omeprazole
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ec9a18259fca> in <cell line: 1>()
# ----> 1 omeprazole
#
# NameError: name 'omeprazole' is not defined

# %%
'omeprazole'
# Out:
# 'omeprazole'

# %%
'omeprazole'[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-d5a6d256d319> in <cell line: 1>()
# ----> 1 'omeprazole'[10]
#
# IndexError: string index out of range

# %%
'omeprazole'[9]
# Out:
# 'e'

# %%
'omeprazole' + 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ffa67f77d240> in <cell line: 1>()
# ----> 1 'omeprazole' + 0
#
# TypeError: can only concatenate str (not "int") to str

# %%
'es' + 'omeprazole'
# Out:
# 'esomeprazole'

# %%
def welcome():
print("welcome to our pharmacy")
# Out:
#   File "<ipython-input-9-9c070a2204f1>", line 2
#     print("welcome to our pharmacy")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def welcome():
    print("welcome to our pharmacy")

# %%
welcome()
# Out:
# welcome to our pharmacy

# %%
print "welcome to our pharmacy"
# Out:
#   File "<ipython-input-12-485848317b6a>", line 1
#     print "welcome to our pharmacy"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("welcome to our pharmacy")
# Out:
# welcome to our pharmacy
