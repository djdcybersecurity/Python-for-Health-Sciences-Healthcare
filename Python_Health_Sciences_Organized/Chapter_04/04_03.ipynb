# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-724ba28f4a9a> in <cell line: 1>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(False)
# Out:
# bool

# %%
sample_bool = True
print(sample_bool)
# Out:
# True

# %%
True = "sample"
# Out:
#   File "<ipython-input-6-976ae6b55182>", line 1
#     True = "sample"
#     ^
# SyntaxError: cannot assign to True

# %%
True == 1
# Out:
# True

# %%
True == 0
# Out:
# False

# %%
False == 0
# Out:
# True
