# %%
omeprazole is a proton pump inhibitor
# Out:
#   File "<ipython-input-1-aff119e71931>", line 1
#     omeprazole is a proton pump inhibitor
#                     ^
# SyntaxError: invalid syntax

# %%
'omeprazole is a proton pump inhibitor'
# Out:
# 'omeprazole is a proton pump inhibitor'

# %%
"omeprazole is a proton pump inhibitor"
# Out:
# 'omeprazole is a proton pump inhibitor'

# %%
"""omeprazole is a proton pump inhibitor"""
# Out:
# 'omeprazole is a proton pump inhibitor'

# %%
sample_string = "omeprazole"
print(sample_string)
# Out:
# omeprazole

# %%
type(sample_string)
# Out:
# str

# %%
type('k')
# Out:
# str

# %%
print(""" 'omeprazole is a proton pump inhibitor.'  'omeprazole is a proton pump inhibitor.'""")
# Out:
#  'omeprazole is a proton pump inhibitor.'  'omeprazole is a proton pump inhibitor.'

# %%
print(""" 'omeprazole is a proton pump inhibitor.' \n  'omeprazole is a proton pump inhibitor.'""")
# Out:
#  'omeprazole is a proton pump inhibitor.'
#   'omeprazole is a proton pump inhibitor.'
