# %%
quantity_of_omeprazole = 60
if quantity_of_omeprazole > 40:
    print("there is enough omeprazole to dispense")
else:
     print("there is less than 40 omeprazole in the dispensary, would you like to dispense esomeprazole?")
# Out:
# there is enough omeprazole to dispense

# %%
quantity_of_omeprazole = 39
if quantity_of_omeprazole > 40:
    print("there is enough omeprazole to dispense")
else:
     print("there is less than 40 omeprazole in the dispensary, would you like to dispense esomeprazole?")
# Out:
# there is less than 40 omeprazole in the dispensary, would you like to dispense esomeprazole?

# %%
quantity_of_omeprazole = 60
if quantity_of_omeprazole > 40:
    print("there is enough omeprazole to dispense")
elif quantity_of_omeprazole < 40:
     print("there is less than 40 omeprazole in the dispensary, would you like to dispense esomeprazole?")
# Out:
# there is enough omeprazole to dispense
