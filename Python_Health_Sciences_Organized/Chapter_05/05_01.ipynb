# %%
[]
# Out:
# []

# %%
type([])
# Out:
# list

# %%
sample_list = ['paracetamol','aspirin','ibuprofen','naproxen','piroxicam','tramadol']
sample_list
# Out:
# ['paracetamol', 'aspirin', 'ibuprofen', 'naproxen', 'piroxicam', 'tramadol']

# %%
sample_list.append('diclofenac')
sample_list
# Out:
# ['paracetamol',
#  'aspirin',
#  'ibuprofen',
#  'naproxen',
#  'piroxicam',
#  'tramadol',
#  'diclofenac']

# %%
sample_list.remove('diclofenac')
sample_list
# Out:
# ['paracetamol', 'aspirin', 'ibuprofen', 'naproxen', 'piroxicam', 'tramadol']

# %%
sample_list[0]
# Out:
# 'paracetamol'

# %%
 sample_list[-1]
# Out:
# 'tramadol'

# %%
sample_list.insert(5,'diclofenac')
sample_list
# Out:
# ['paracetamol',
#  'aspirin',
#  'ibuprofen',
#  'naproxen',
#  'piroxicam',
#  'diclofenac',
#  'tramadol']

# %%
sample_list_copy = sample_list.copy()
sample_list_copy
# Out:
# ['paracetamol',
#  'aspirin',
#  'ibuprofen',
#  'naproxen',
#  'piroxicam',
#  'diclofenac',
#  'tramadol']

# %%
sample_list_copy.reverse()
sample_list_copy
# Out:
# ['tramadol',
#  'diclofenac',
#  'piroxicam',
#  'naproxen',
#  'ibuprofen',
#  'aspirin',
#  'paracetamol']

# %%
sample_list_copy.sort()
sample_list_copy
# Out:
# ['aspirin',
#  'diclofenac',
#  'ibuprofen',
#  'naproxen',
#  'paracetamol',
#  'piroxicam',
#  'tramadol']

# %%
sample_list_numeric =[1,12,23,34,90,80,70,67]
sample_list_numeric
# Out:
# [1, 12, 23, 34, 90, 80, 70, 67]

# %%
sample_list_numeric.sort()
sample_list_numeric
# Out:
# [1, 12, 23, 34, 67, 70, 80, 90]

# %%
sample_list_numeric.pop()
# Out:
# 90

# %%
sample_list_numeric
# Out:
# [1, 12, 23, 34, 67, 70, 80]
