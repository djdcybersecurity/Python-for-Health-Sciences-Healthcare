# %%
sample_set = {"omeprazole","rabeprazole","pantoprazole","rabeprazole","lansoprazole"}

# %%
sample_set
# Out:
# {'lansoprazole', 'omeprazole', 'pantoprazole', 'rabeprazole'}

# %%
type(sample_set)
# Out:
# set

# %%
sample_patient_set = {"kuki",50,123321,"kukiland"}
print(type(sample_patient_set))
sample_patient_set
# Out:
# <class 'set'>
# {123321, 50, 'kuki', 'kukiland'}

# %%
"omeprazole" in sample_set
# Out:
# True

# %%
"esomeprazole" in sample_set
# Out:
# False

# %%
sample_set.add("esomeprazole")

# %%
sample_set
# Out:
# {'esomeprazole', 'lansoprazole', 'omeprazole', 'pantoprazole', 'rabeprazole'}

# %%
sample_set.remove("esomeprazole")

# %%
sample_set
# Out:
# {'lansoprazole', 'omeprazole', 'pantoprazole', 'rabeprazole'}

# %%
sample_set.pop()
# Out:
# 'pantoprazole'

# %%
sample_set
# Out:
# {'lansoprazole', 'omeprazole', 'rabeprazole'}

# %%
sample_set.union(sample_patient_set)
# Out:
# {123321, 50, 'kuki', 'kukiland', 'lansoprazole', 'omeprazole', 'rabeprazole'}
