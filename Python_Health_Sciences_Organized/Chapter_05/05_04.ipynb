# %%
sample_dictionary = {"paracetamol": 500, "ibuprofen": 200, "aspirin": 325, "tramadol" : 50}
sample_dictionary
# Out:
# {'paracetamol': 500, 'ibuprofen': 200, 'aspirin': 325, 'tramadol': 50}

# %%
type(sample_dictionary)
# Out:
# dict

# %%
sample_dictionary_antihypetensives = {"diuretics":["spironolactone","furosemide","hydrochlorothiazide"],"beta blockers": ["atenolol","propranolol","metoprolol"],"ACEI":["lisinopril","enalapril","ramipril"]}
sample_dictionary_antihypetensives
# Out:
# {'diuretics': ['spironolactone', 'furosemide', 'hydrochlorothiazide'],
#  'beta blockers': ['atenolol', 'propranolol', 'metoprolol'],
#  'ACEI': ['lisinopril', 'enalapril', 'ramipril']}

# %%
type(sample_dictionary_antihypetensives)
# Out:
# dict

# %%
sample_dictionary_antihypetensives["beta blockers"]
# Out:
# ['atenolol', 'propranolol', 'metoprolol']

# %%
sample_dictionary_antihypetensives["beta blockers"][1]
# Out:
# 'propranolol'

# %%
sample_dictionary_antihypetensives.keys()
# Out:
# dict_keys(['diuretics', 'beta blockers', 'ACEI'])

# %%
sample_dictionary_antihypetensives.update({"Ca blockers": ["amlodipine","nifedipine","verpamil"]})

# %%
sample_dictionary_antihypetensives
# Out:
# {'diuretics': ['spironolactone', 'furosemide', 'hydrochlorothiazide'],
#  'beta blockers': ['atenolol', 'propranolol', 'metoprolol'],
#  'ACEI': ['lisinopril', 'enalapril', 'ramipril'],
#  'Ca blockers': ['amlodipine', 'nifedipine', 'verpamil']}

# %%
patient_info_dictionary = dict(name="kuki", age=20, nationality="kukiland")
patient_info_dictionary
# Out:
# {'name': 'kuki', 'age': 20, 'nationality': 'kukiland'}
