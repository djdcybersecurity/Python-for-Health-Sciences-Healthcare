# %% [markdown]
# ##Length - len()

# %%
len("omeprazole")
# Out:
# 10

# %%
len(["omeprazole","rabeprazole","esomeprazole"])
# Out:
# 3

# %%
len(" ")
# Out:
# 1

# %% [markdown]
# ##Count - Count()

# %%
names_of_ppi = ["omeprazole","rabeprazole","esomeprazole"]

# %%
names_of_ppi.count("o")
# Out:
# 0

# %%
"omeprazole".count("o")
# Out:
# 2

# %%
names_of_ppi.count("omeprazole")
# Out:
# 1
