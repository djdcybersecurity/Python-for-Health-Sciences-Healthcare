# %%
laboratory_apparatus = "Some of the appartaus found in the laboratory are test tube,beaker,pipette,glass funnel and petri dish"

# %%
laboratory_apparatus.split()
# Out:
# ['Some',
#  'of',
#  'the',
#  'appartaus',
#  'found',
#  'in',
#  'the',
#  'laboratory',
#  'are',
#  'test',
#  'tube,beaker,pipette,glass',
#  'funnel',
#  'and',
#  'petri',
#  'dish']

# %%
laboratory_apparatus.split(",")
# Out:
# ['Some of the appartaus found in the laboratory are test tube',
#  'beaker',
#  'pipette',
#  'glass funnel and petri dish']

# %%
list_of_lab_apparatus = ['test tube','beaker','pipette','burette']

# %%
"".join(list_of_lab_apparatus)
# Out:
# 'test tubebeakerpipetteburette'

# %%
" ".join(list_of_lab_apparatus)
# Out:
# 'test tube beaker pipette burette'

# %%
",".join(list_of_lab_apparatus)
# Out:
# 'test tube,beaker,pipette,burette'
