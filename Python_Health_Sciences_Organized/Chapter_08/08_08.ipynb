# %%
height_of_children_in_meters = [1.20,1.25,1.30,1.33,1.35,1.50]

# %%
def square(number):
    return number **2

# %%
square_of_height_of_children_in_meters = list(map(square,height_of_children_in_meters))
square_of_height_of_children_in_meters
# Out:
# [1.44,
#  1.5625,
#  1.6900000000000002,
#  1.7689000000000001,
#  1.8225000000000002,
#  2.25]

# %%
list(map(lambda x: x ** 2, height_of_children_in_meters))
# Out:
# [1.44,
#  1.5625,
#  1.6900000000000002,
#  1.7689000000000001,
#  1.8225000000000002,
#  2.25]
