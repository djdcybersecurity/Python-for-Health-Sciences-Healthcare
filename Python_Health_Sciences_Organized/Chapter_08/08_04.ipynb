# %%
sample_statement = "Public health refers to the Science and Practice of protecting,promoting and improving Health and Well being of populations"

# %%
sample_statement.upper()
# Out:
# 'PUBLIC HEALTH REFERS TO THE SCIENCE AND PRACTICE OF PROTECTING,PROMOTING AND IMPROVING HEALTH AND WELL BEING OF POPULATIONS'

# %%
sample_statement.lower()
# Out:
# 'public health refers to the science and practice of protecting,promoting and improving health and well being of populations'

# %%
sample_statement.capitalize()
# Out:
# 'Public health refers to the science and practice of protecting,promoting and improving health and well being of populations'

# %%
sample_statement.title()
# Out:
# 'Public Health Refers To The Science And Practice Of Protecting,Promoting And Improving Health And Well Being Of Populations'
