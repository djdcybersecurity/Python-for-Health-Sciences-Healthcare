# %% [markdown]
# ##Minimum - min()

# %%
ibuprofen_strength_in_mg = [200,300,400,600,800]

# %%
min(ibuprofen_strength_in_mg)
# Out:
# 200

# %% [markdown]
# ##Maximim - max()

# %%
max(ibuprofen_strength_in_mg)
# Out:
# 800
