# %%
5 == 5.0
# Out:
# True

# %%
5 < (100/20)
# Out:
# False

# %%
5 == 5.0 and 5 < (100/20)
# Out:
# False

# %%
5 == 5.0 or 5 < (100/20)
# Out:
# True

# %%
5 == 5.0 and not 5 < (100/20)
# Out:
# True
