# %% [markdown]
# #Integers(int)

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
sample_numeric = 5

# %%
sample_numeric
# Out:
# 5

# %%
print(sample_numeric)
# Out:
# 5

# %%
type(sample_numeric)
# Out:
# int

# %% [markdown]
# #Floating data point(float)

# %%
5.0
# Out:
# 5.0

# %%
type(5.0)
# Out:
# float

# %%
sample_float = 5.0
print(sample_float)
print(type(sample_float))
# Out:
# 5.0
# <class 'float'>

# %%
int(5.60)
# Out:
# 5
