# %%
"Laboratory"[0:3]
# Out:
# 'Lab'

# %%
lab_apparatus = ["test tube","petri dish","beaker","glass funnel"]

# %%
lab_apparatus[0:2]
# Out:
# ['test tube', 'petri dish']

# %%
lab_apparatus[-1]
# Out:
# 'glass funnel'

# %%
lab_apparatus[3]
# Out:
# 'glass funnel'

# %%
lab_apparatus[-2:]
# Out:
# ['beaker', 'glass funnel']
