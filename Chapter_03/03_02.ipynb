# %% [markdown]
# ##Create a python file

# %%
# %%writefile demo_python_file.py
# Out:
# Writing demo_python_file.py

# %% [markdown]
# ##Write Python File

# %%
with open('/content/demo_python_file.py','w') as file:
    file.write('welcome again')
