# %%
# %%writefile how_to_use_a_fume_cupboard.py
# Out:
# Writing how_to_use_a_fume_cupboard.py

# %% [markdown]
# ##Read Python File

# %%
filename = '/content/how_to_use_a_fume_cupboard.py'

with open(filename, 'r') as file:
    print(file.read())
# Out:
#  """
#  Check the standard operating procedure for the fume cupboard.Ensure you have the proper safety gear
#  Familiarize yourself with the control knobs.Ensure the fume cupboard is empty
#  Ensure the exhaust outlet is well positioned , the airflow knobs are activated
#  If electric ensure the fume cupboard is plugged in.now carefully carry out your experiment
#  """

# %%
with open(filename, 'r') as file:
    lines = file.readlines()
    print(lines)
# Out:
# [' """\n', ' Check the standard operating procedure for the fume cupboard.Ensure you have the proper safety gear\n', ' Familiarize yourself with the control knobs.Ensure the fume cupboard is empty\n', ' Ensure the exhaust outlet is well positioned , the airflow knobs are activated\n', ' If electric ensure the fume cupboard is plugged in.now carefully carry out your experiment\n', ' """']
