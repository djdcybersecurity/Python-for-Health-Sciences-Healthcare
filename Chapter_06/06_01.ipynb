# %% [markdown]
# ##Addition(+)

# %% [markdown]
# ###Integer

# %%
4 + 4
# Out:
# 8

# %% [markdown]
# ###Float

# %%
4.5 + 4.5
# Out:
# 9.0

# %% [markdown]
# ###String

# %%
"hydro" + "chlorothiazide"
# Out:
# 'hydrochlorothiazide'

# %% [markdown]
# ###List

# %%
analgesics = ["paracetamol","ibuprofen","diclofenac"]
dosage_strenghth_in_mg = [500,200,50]
analgesics + dosage_strenghth_in_mg
# Out:
# ['paracetamol', 'ibuprofen', 'diclofenac', 500, 200, 50]

# %% [markdown]
# ##Subtraction(-)

# %% [markdown]
# ###Integer

# %%
value_1 = 100
value_2 = 20

# %%
value_1 - value_2
# Out:
# 80

# %%
value_2 - value_1
# Out:
# -80

# %%
"500mg" - "200mg"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e35645967c08> in <cell line: 1>()
# ----> 1 "500mg" - "200mg"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
[100,200,300] - [20,40,60]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-cfd591b7e5b5> in <cell line: 1>()
# ----> 1 [100,200,300] - [20,40,60]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# ##Multiplication(*)

# %% [markdown]
# ###Integer

# %%
5 * 5
# Out:
# 25

# %% [markdown]
# ###Float

# %%
float_1 = 4.5
float_2 = 3.124

# %%
float_combined = float_1 * float_2
float_combined
# Out:
# 14.058

# %% [markdown]
# ###String

# %%
"omeprazole" * 3
# Out:
# 'omeprazoleomeprazoleomeprazole'

# %% [markdown]
# ###List

# %%
analgesics = ["paracetamol","ibuprofen","diclofenac"]
analgesics * 3
# Out:
# ['paracetamol',
#  'ibuprofen',
#  'diclofenac',
#  'paracetamol',
#  'ibuprofen',
#  'diclofenac',
#  'paracetamol',
#  'ibuprofen',
#  'diclofenac']

# %%
dosage_strenghth_in_mg = [500,200,50]
dosage_strenghth_in_mg * 3
# Out:
# [500, 200, 50, 500, 200, 50, 500, 200, 50]

# %% [markdown]
# ##Power(**)

# %% [markdown]
# ###Integer

# %%
5 ** 4
# Out:
# 625

# %%
power_number  = 5
power_number ** 4
# Out:
# 625

# %% [markdown]
# ###Float

# %%
5.4 ** 5
# Out:
# 4591.650240000002

# %% [markdown]
# ##Division(/)

# %% [markdown]
# ###Integer

# %%
100/5
# Out:
# 20.0

# %%
value_1 / value_2
# Out:
# 5.0

# %% [markdown]
# ###Float

# %%
1.5/2
# Out:
# 0.75

# %%
100.5/2.5
# Out:
# 40.2
